# %%
#DATA ANALYSIS AND INTERPRITATION
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/abhishekchauhan/Desktop/hrdataset.csv")
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
df.size
# Out:
# 100000

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %%
df1=df.copy()
df1
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
df1
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
#filling empty cell of total sales with nan
df=df.replace(r'^\s*$', float(np.NaN), regex=True)

# %%
#to check weather that values are replaced with nan or not
df.tail()
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay     Bonus  Unit_Price   Volume  openingbalance  \
# 4995  180696.80  72278.720  9034.840  629.511067  3927000             NaN
# 4996  185685.90  74274.360  9284.295  627.841071  6031900             NaN
# 4997  192636.80  77054.720  9631.840  625.860033  7949400             NaN
# 4998  195970.70  78388.280  9798.535  629.510005  3908400             NaN
# 4999  199970.74  79988.296  9998.537  627.839984  6003300             NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
df['Total_Sales']= df['Total_Sales'].astype('float64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
missing_values= df.isnull().sum()
missing_values
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales         16
# Months               0
# Education            0
# dtype: int64

# %%
#calculating percentage of missing values
total = df.isnull().sum().sort_values(ascending=False)  # TOTAL count of missing values per column
percent_1 = (df.isnull().sum() / df.shape[0]) * 100 #percentage of missing values per columns
percent_2 = round(percent_1,1).sort_values(ascending=False)   #percentage rounded to 1 decimal
missing_data = pd.concat([total,percent_2],axis=1, keys=['Total','%'])   #concatenate the two data. #Series into data frame
missing_data.head(3)# Display the top 3 columns with missing data
# Out:
#                 Total     %
# openingbalance   1476  29.5
# Base_pay           23   0.5
# Total_Sales        16   0.3

# %%
from sklearn.impute import KNNImputer
x= df[['Base_pay','openingbalance','Total_Sales']]  #create an object
imputer = KNNImputer(n_neighbors=2)    #fit andtransform the value
#KNIImputer is used to replace the value to make it null or 0
x = imputer.fit_transform(x)

# %%
#converting the array into dataframe
df[['Base_pay','openingbalance','Total_Sales']]=pd.DataFrame(x, columns=['Base_pay','openingbalance','Total_Sales'])

# %%
df.isna().sum()
# Out:
# Gender            0
# Business          0
# Dependancies      0
# Calls             0
# Type              0
# Billing           0
# Rating            0
# Age               0
# Salary            0
# Base_pay          0
# Bonus             0
# Unit_Price        0
# Volume            0
# openingbalance    0
# closingbalance    0
# low               0
# Unit_Sales        0
# Total_Sales       0
# Months            0
# Education         0
# dtype: int64

# %%
# checking the total employee education wise
degree_wise=df.Education.value_counts()  #counting degree wise employee
degree_wise                              #degree wise employee
# Out:
# Education
# PG                     2979
# Graduation             1980
# Intermediate             27
# High School or less      14
# Name: count, dtype: int64

# %%
Gender_wise=df.Gender.value_counts()    #counting total number of the employee gender wise
Gender_wise                             #gender wise employee
# Out:
# Gender
# Male      2528
# Female    2472
# Name: count, dtype: int64

# %%
#counting how many employees have benn rated by supervisor
Rating_wise=df.Rating.value_counts()    #counting the total number of rating employee wise
Rating_wise
# Out:
# Rating
# No     3682
# Yes    1318
# Name: count, dtype: int64

# %%
#counting how manh employee authority to call
Call_wise=df.Calls.value_counts()       #counting the total number of employee who has the authority to call.
Call_wise
# Out:
# Calls
# Yes    4539
# No      461
# Name: count, dtype: int64

# %%
# counting number of people dependent on the person
Dependancies_wise=df.Dependancies.value_counts()   #number of people dependent on the empoyee.
Dependancies_wise
# Out:
# Dependancies
# No     3524
# Yes    1476
# Name: count, dtype: int64

# %%
Age_wise=df.Age.value_counts() #counting the total number of employee age wise.
Age_wise                       #age wise employee
# Out:
# Age
# 50    256
# 53    254
# 55    248
# 54    245
# 51    244
#      ...
# 78      2
# 80      1
# 82      1
# 85      1
# 79      1
# Name: count, Length: 65, dtype: int64

# %%
#checking count of salary settlement type
Type_wise=df.Type.value_counts()    #counting employee salary settlement type
Type_wise                           #no. of employee settlement type.
# Out:
# Type
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: count, dtype: int64

# %%
# checking no. of employee subscribed to billing plans or no
Billing_wise=df.Billing.value_counts() #counting employee who have subscribe billing plan or no
Billing_wise #employee billing
# Out:
# Billing
# Yes    2956
# No     2044
# Name: count, dtype: int64

# %%
#setting a grey background
sns.set_style("darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# ploting subplots with numerical value
sns.histplot(data=df, x="Salary", kde=True, color="red", ax=axs[0, 0]) #kde= kernal density the line shown in graph
sns.histplot(data=df, x="Base_pay", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df, x="Bonus", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df, x="Age", kde=True, color="black", ax=axs[1, 1])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
fig,axs = plt.subplots(1, 2, figsize=(10, 5))
sns.histplot(data=df, x="low", kde=True, color="red", ax=axs[0])          #histrogrm for low column
sns.histplot(data=df, x="Total_Sales", kde=True, color="Navy", ax=axs[1]) #histrogram for total_sales column
plt.show()

# %%
#setting a grey background
sns.set_style("darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(3, 2, figsize=(10, 10))
# ploting subplots with numerical value
sns.histplot(data=df, x="Salary", kde=True, color="red", ax=axs[0, 0])           #kde= kernal density the line shown in graph
sns.histplot(data=df, x="Base_pay", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df, x="Bonus", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df, x="Age", kde=True, color="black", ax=axs[1, 1])
sns.histplot(data=df, x="low", kde=True, color="red", ax=axs[2,0])               #histrogrm for low column
sns.histplot(data=df, x="Total_Sales", kde=True, color="Navy", ax=axs[2,1])      #histrogram for total_sales column
# Out:
# <Axes: xlabel='Total_Sales', ylabel='Count'>

# %%
#setting a grey background
sns.set_style("darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# ploting subplots with variable
sns.boxplot(data=df, x="Salary", color="red", ax=axs[0, 0]) #kde= kernal density (the line shown in graph)
sns.boxplot(data=df, x="Base_pay", color="olive", ax=axs[0, 1])
sns.boxplot(data=df, x="Bonus", color="gold", ax=axs[1, 0])
sns.boxplot(data=df, x="Age", color="black", ax=axs[1, 1])
# Out:
# <Axes: xlabel='Age'>

# %%
#setting a grey background
sns.set_style("darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# ploting subplots with all variable
#kde= kernal density the line shown in graph
sns.boxplot(data=df, x="Unit_Price", color="red", ax=axs[0, 0])
sns.boxplot(data=df, x="Unit_Sales", color="olive", ax=axs[0, 1])
sns.boxplot(data=df, x="openingbalance",  color="gold", ax=axs[1, 0])
sns.boxplot(data=df, x="closingbalance", color="black", ax=axs[1, 1])
# Out:
# <Axes: xlabel='closingbalance'>

# %%
#setting a grey background
sns.set_style("darkgrid")
# Creating subplots with 10*10 figure size
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# ploting subplots with variable
#kde= kernal density the line shown in graph
sns.boxplot(data=df, x="low", color="red", ax=axs[0, 0])
sns.boxplot(data=df, x="Total_Sales", color="olive", ax=axs[0, 1])
sns.boxplot(data=df, x="Volume",  color="gold", ax=axs[1, 0])
sns.boxplot(data=df, x="Months", color="blue", ax=axs[1, 1])
# Out:
# <Axes: xlabel='Months'>

# %%
#QQplot is used to for Statistical approach tp see the distribution
# !pip install pingouin ##installing libraries

# %%
df.dtypes
# Out:
# Gender             object
# Business            int64
# Dependancies       object
# Calls              object
# Type               object
# Billing            object
# Rating             object
# Age                 int64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume              int64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales       float64
# Months              int64
# Education          object
# dtype: object

# %%
#QQ plot salary
import pingouin as pg
pg.qqplot(df['Salary'],dist ='norm')  #To find the normal distribution
# ( If blue line is with(attached) to the red line so it is normal distribution otherwise not a noramal distribution)
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Base_pay'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Bonus'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Unit_Price'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Volume'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Age'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['closingbalance'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['openingbalance'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['low'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Months'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
df3 =df.drop(['Business'],axis = 1)    #drop(remove) the business columns bcz it is categorical data
df3.head()
# Out:
#    Gender Dependancies Calls            Type Billing Rating  Age   Salary  \
# 0  Female           No   Yes  Month-to-month      No    Yes   18  5089.00
# 1  Female           No   Yes  Month-to-month      No    Yes   19  5698.12
# 2    Male           No   Yes  Month-to-month     Yes     No   22  5896.65
# 3  Female           No   Yes  Month-to-month     Yes    Yes   21  6125.12
# 4    Male           No   Yes  Month-to-month     Yes    Yes   23  6245.00
#
#    Base_pay     Bonus  Unit_Price    Volume  openingbalance  closingbalance  \
# 0  2035.600  254.4500        3.77  21226600            3.75            3.76
# 1  2279.248  284.9060        3.74  10462800            3.85            3.68
# 2  2358.660  294.8325        3.89  18761000            4.23            4.29
# 3  2450.048  306.2560        4.35  66130600            4.26            4.31
# 4  2498.000  312.2500        4.34  26868200            4.79            4.41
#
#     low  Unit_Sales  Total_Sales  Months            Education
# ...

# %%
df3_numeric = df3.select_dtypes(include='number')

# %%
#spearman rank correlation heatmap
df3_numeric.corr(method="spearman")     #selecting the method as a spearman
plt.figure(figsize=(20,8))              #setting the figure size
heatmap = sns.heatmap(df3_numeric.corr(method = "spearman").round(3), vmin= -1, vmax=1, annot=True)
#annot = True means writting the data value in each cell MEANS to write the vales cells ke andar
font2= {'family':'serif','color':'green','size':20}
plt.title("spearman Rank Correlation",font2)
plt.show() #displaying heatmap

# %%
#looking the categorical columns
df.select_dtypes(include='object').columns.tolist()
# Out:
# ['Gender', 'Dependancies', 'Calls', 'Type', 'Billing', 'Rating', 'Education']

# %%
df.dtypes
# Out:
# Gender             object
# Business            int64
# Dependancies       object
# Calls              object
# Type               object
# Billing            object
# Rating             object
# Age                 int64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume              int64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales       float64
# Months              int64
# Education          object
# dtype: object

# %%
plt.figure(figsize=(9,8))     #size of the figure
sns.boxplot(data=df,x="Gender",y="Salary",palette="viridis")     #plotting the box plot for salary vs gender
plt.title("Salary vs Gender")   #plot title.
# Out:
# /var/folders/4s/66hlcwmx7wd9986vc_nb32yr0000gp/T/ipykernel_9135/671184104.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x="Gender",y="Salary",palette="viridis")     #plotting the box plot for salary vs gender
# Text(0.5, 1.0, 'Salary vs Gender')

# %%
plt.figure(figsize=(9,8))                                  #size of the figure
sns.boxplot(data=df,x="Education",y="Salary",palette="magma")     #plotting the box plot for salary vs EDUCATION
plt.title("Salary vs Education")                              #plot title.
# Out:
# /var/folders/4s/66hlcwmx7wd9986vc_nb32yr0000gp/T/ipykernel_9135/482741363.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x="Education",y="Salary",palette="magma")     #plotting the box plot for salary vs EDUCATION
# Text(0.5, 1.0, 'Salary vs Education')

# %%
plt.figure(figsize=(9,8))                                  #size of the figure
sns.boxplot(data=df,x="Type",y="Salary",palette="viridis")     #plotting the box plot for salary vs TYPE
plt.title("Salary vs Type")                              #plot title.
# Out:
# /var/folders/4s/66hlcwmx7wd9986vc_nb32yr0000gp/T/ipykernel_9135/4265222687.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x="Type",y="Salary",palette="viridis")     #plotting the box plot for salary vs TYPE
# Text(0.5, 1.0, 'Salary vs Type')

# %%
plt.figure(figsize=(9,8))                                  #size of the figure
sns.boxplot(data=df,x="Rating",y="Salary",palette="mako")     #plotting the box plot for salary vs Rating
plt.title("Salary vs Rating")                              #plot title.
# Out:
# /var/folders/4s/66hlcwmx7wd9986vc_nb32yr0000gp/T/ipykernel_9135/2129865152.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x="Rating",y="Salary",palette="mako")     #plotting the box plot for salary vs Rating
# Text(0.5, 1.0, 'Salary vs Rating')

# %%
plt.figure(figsize=(9,8))                                  #size of the figure
sns.boxplot(data=df,x="Dependancies",y="Salary",palette="rocket")     #plotting the box plot for salary vs Dependancies
plt.title("Dependancies vs Salary")                              #plot title.
# Out:
# /var/folders/4s/66hlcwmx7wd9986vc_nb32yr0000gp/T/ipykernel_9135/67846596.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x="Dependancies",y="Salary",palette="rocket")     #plotting the box plot for salary vs Dependancies
# Text(0.5, 1.0, 'Dependancies vs Salary')

# %%
plt.figure(figsize=(9,8))                                  #size of the figure
sns.boxplot(data=df,x="Calls",y="Salary",palette="viridis")     #plotting the box plot for salary vs Calls
plt.title("Calls vs Salary")                              #plot title.
# Out:
# /var/folders/4s/66hlcwmx7wd9986vc_nb32yr0000gp/T/ipykernel_9135/1466562632.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x="Calls",y="Salary",palette="viridis")     #plotting the box plot for salary vs Calls
# Text(0.5, 1.0, 'Calls vs Salary')

# %%
plt.figure(figsize=(9,8))                                  #size of the figure
sns.boxplot(data=df,x="Billing",y="Salary",palette="icefire")     #plotting the box plot for salary vs Billing
plt.title("Billing vs Salary")                              #plot title.
# Out:
# /var/folders/4s/66hlcwmx7wd9986vc_nb32yr0000gp/T/ipykernel_9135/495839189.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x="Billing",y="Salary",palette="icefire")     #plotting the box plot for salary vs Billing
# Text(0.5, 1.0, 'Billing vs Salary')

# %%
df.dtypes
# Out:
# Gender             object
# Business            int64
# Dependancies       object
# Calls              object
# Type               object
# Billing            object
# Rating             object
# Age                 int64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume              int64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales       float64
# Months              int64
# Education          object
# dtype: object

# %%
plt.figure(figsize=(9,5))
plt.xlabel('Base_pay',fontsize=15)
plt.ylabel('Salary',fontsize=15)
plt.title('Base_pay vs Salary',fontsize=15)
sns.scatterplot(x=df['Base_pay'],y=df['Salary'],color='Black')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('  Age',fontsize=15)
plt.ylabel('Salary',fontsize=15)
plt.title('Age vs Salary',fontsize=15)
sns.scatterplot(x=df['Age'],y=df['Salary'],color='Black')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('  Volume',fontsize=15)
plt.ylabel('Salary',fontsize=15)
plt.title('Volume vs Salary',fontsize=15)
sns.scatterplot(x=df['Volume'],y=df['Salary'],color='Black')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('openingbalance',fontsize=15)
plt.ylabel('Salary',fontsize=15)
plt.title('openingbalance vs Salary',fontsize=15)
sns.scatterplot(x=df['openingbalance'],y=df['Salary'],color='Black')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('closingbalance',fontsize=15)
plt.ylabel('Salary',fontsize=15)
plt.title('closingbalance vs Salary',fontsize=15)
sns.scatterplot(x=df['closingbalance'],y=df['Salary'],color='Black')
plt.show()

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Age")#boxplot of the age

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Business")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Base_pay")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Salary")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Bonus")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Unit_Price")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Volume")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="openingbalance")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="closingbalance")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="low")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Unit_Sales")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Months")

# %%
plt.figure(figsize=(10,8))#size of the figure
figure=df.boxplot(column="Total_Sales")

# %%
df3_numeric.corr(method='spearman')*100#looking to the percentage of correlation
# Out:
#                        Age      Salary    Base_pay       Bonus  Unit_Price  \
# Age             100.000000   20.228180   20.212073   20.228180   12.826637
# Salary           20.228180  100.000000   99.997589  100.000000   81.171311
# Base_pay         20.212073   99.997589  100.000000   99.997589   81.168113
# Bonus            20.228180  100.000000   99.997589  100.000000   81.171311
# Unit_Price       12.826637   81.171311   81.168113   81.171311  100.000000
# Volume           -3.934477  -39.048779  -39.042656  -39.048779  -32.422983
# openingbalance   -5.291931   45.346909   45.285139   45.346909   33.340773
# closingbalance   44.098882   34.649833   34.640860   34.649833   26.369923
# low              20.203950   99.985870   99.983405   99.985870   81.241207
# Unit_Sales       20.226808   99.999741   99.997324   99.999741   81.173482
# Total_Sales      20.217192   99.996492   99.994077   99.996492   81.170424
# ...

# %%
# Dropping the non-required variables
dff = df.drop(columns=['Gender','Business','Dependancies','Calls','Type','Billing',
                       'Rating','Base_pay','Unit_Price','low','Unit_Sales',
                       'Total_Sales','openingbalance','closingbalance','Volume','Bonus'])
dff.head()
# Out:
#    Age   Salary  Months            Education
# 0   18  5089.00       0  High School or less
# 1   19  5698.12       0  High School or less
# 2   22  5896.65       0  High School or less
# 3   21  6125.12       0  High School or less
# 4   23  6245.00       1  High School or less

# %%
#label encoding to convert cateograical data to into numerical data

dff['Education']=dff['Education'].map({'High School or less': 0, 'Intermediate': 1,
                                       'Graduation': 2, 'PG': 3})
dff.head()
#assigning high school =0,Intermediate =1 and gradaution=2
# Out:
#    Age   Salary  Months  Education
# 0   18  5089.00       0          0
# 1   19  5698.12       0          0
# 2   22  5896.65       0          0
# 3   21  6125.12       0          0
# 4   23  6245.00       1          0

# %%
Q1=dff.quantile(0.25).round(3) #taking lower quantile into Q2
Q3=dff.quantile(0.75).round(3) #taking upper quantile into Q3
IQR=Q3-Q1 #calculating inter quantile ramge
print(IQR)
# Out:
# Age             10.000
# Salary       33021.753
# Months          47.000
# Education        1.000
# dtype: float64

# %%
dfout = dff[~((dff < (Q1 - 1.5 * IQR)) |(dff > (Q3 + 1.5 * IQR))).any(axis=1)] #removing outliers
dfout.shape
# Out:
# (4833, 4)

# %%
sns.boxplot(x=dfout['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df.dtypes
# Out:
# Gender             object
# Business            int64
# Dependancies       object
# Calls              object
# Type               object
# Billing            object
# Rating             object
# Age                 int64
# Salary            float64
# Base_pay          float64
# Bonus             float64
# Unit_Price        float64
# Volume              int64
# openingbalance    float64
# closingbalance    float64
# low               float64
# Unit_Sales        float64
# Total_Sales       float64
# Months              int64
# Education          object
# dtype: object

# %%
sns.boxplot(x=dfout['Months'])
# Out:
# <Axes: xlabel='Months'>

# %%
#MODEL BUILDING
x=dff.drop(['Salary'],axis=1)
x
# Out:
#       Age  Months  Education
# 0      18       0          0
# 1      19       0          0
# 2      22       0          0
# 3      21       0          0
# 4      23       1          0
# ...   ...     ...        ...
# 4995   72      72          3
# 4996   73      72          3
# 4997   74      72          3
# 4998   74      72          3
# 4999   88      72          3
#
# [5000 rows x 3 columns]

# %%
y =dff['Salary']
y
#print(y.iloc[2858])
# Out:
# 0         5089.00
# 1         5698.12
# 2         5896.65
# 3         6125.12
# 4         6245.00
#           ...
# 4995    180696.80
# 4996    185685.90
# 4997    192636.80
# 4998    195970.70
# 4999    199970.74
# Name: Salary, Length: 5000, dtype: float64

# %%
#machine learning
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train #it pick 70% ramdom data for train
# Out:
#       Age  Months  Education
# 2858   45      21          2
# 1559   47       1          3
# 1441   45       1          3
# 2179   55       7          3
# 1390   44       1          2
# ...   ...     ...        ...
# 4931   63      72          3
# 3264   40      31          3
# 1653   48       2          2
# 2607   62      15          2
# 2732   68      18          2
#
# [3500 rows x 3 columns]

# %%
x_test #it pick 30% random data for test
# Out:
#       Age  Months  Education
# 398    49      12          3
# 3833   39      48          2
# 4836   59      72          3
# 4572   51      68          3
# 636    53      27          3
# ...   ...     ...        ...
# 4554   50      68          3
# 4807   58      72          3
# 1073   64      63          3
# 2906   48      22          3
# 1357   43       1          3
#
# [1500 rows x 3 columns]

# %%
y_train
# Out:
# 2858    104938.82440
# 1559     88835.89005
# 1441     86903.28139
# 2179     96844.15570
# 1390     86096.55833
#             ...
# 4931    151880.35890
# 3264    110244.51700
# 1653     90043.98773
# 2607    101985.79940
# 2732    103369.50500
# Name: Salary, Length: 3500, dtype: float64

# %%
y_test
# Out:
# 398      64631.43297
# 3833    118137.14110
# 4836    143137.34650
# 4572    133346.50250
# 636      73049.74210
#             ...
# 4554    132723.77580
# 4807    141312.27900
# 1073     81265.54772
# 2906    105472.97890
# 1357     85510.67637
# Name: Salary, Length: 1500, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
# fit scaler on training data
x_train = sc.fit_transform(x_train)
#tranform testing data
x_test = sc.fit_transform(x_test)
#x_scaled= (x - mesan(x)/std(x))

# %%
x_train #learn the pattern
# Out:
# array([[-0.79810913, -0.45185117, -1.14142217],
#        [-0.56643739, -1.26180691,  0.79882921],
#        [-0.79810913, -1.26180691,  0.79882921],
#        ...,
#        [-0.45060152, -1.22130912, -1.14142217],
#        [ 1.17110062, -0.69483789, -1.14142217],
#        [ 1.86611582, -0.57334453, -1.14142217]])

# %%
x_test #test use for prediction
# Out:
# array([[-0.33466189, -0.82656926,  0.79795344],
#        [-1.52704391,  0.64298396, -1.08697595],
#        [ 0.85772014,  1.62268612,  0.79795344],
#        ...,
#        [ 1.45391115,  1.25529781,  0.79795344],
#        [-0.45390009, -0.41836003,  0.79795344],
#        [-1.0500911 , -1.27559941,  0.79795344]])

# %%
#there are the some machine learning models
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Create and train the Linear Regression model
model_lr = LinearRegression()
model_lr.fit(x_train, y_train)

# Make predictions
y_pred_lr = model_lr.predict(x_test)

# Calculate performance metrics
mae_lr = mean_absolute_error(y_test, y_pred_lr)
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
mape_lr = np.mean(np.abs((y_test - y_pred_lr) / np.abs(y_test)))
accuracy_lr = 100 * (1 - mape_lr)

# Print the performance metrics for Linear Regression
print('Linear Regression Metrics:')
print('Mean Absolute Error (MAE):', mae_lr)
print('Mean Squared Error (MSE):', mse_lr)
print('Root Mean Squared Error (RMSE):', rmse_lr)
print('Mean Absolute Percentage Error (MAPE):', round(mape_lr * 100, 2))
print('Accuracy:', round(accuracy_lr, 2))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error (MAE): 15282.04821310648
# Mean Squared Error (MSE): 343478271.4972273
# Root Mean Squared Error (RMSE): 18533.16679623931
# Mean Absolute Percentage Error (MAPE): 21.73
# Accuracy: 78.27

# %%
from sklearn.tree import DecisionTreeRegressor

# Create and train the Decision Tree model
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Calculate performance metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
accuracy = 100 * (1 - mape)

# Print the performance metrics
print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# Mean Absolute Error (MAE): 410.9907932964319
# Mean Squared Error (MSE): 4765780.663170201
# Root Mean Squared Error (RMSE): 2183.0668022692757
# Mean Absolute Percentage Error (MAPE): 0.59
# Accuracy: 99.41

# %%
from sklearn.ensemble import RandomForestRegressor

# Create and train RandomForest the model
model_rf = RandomForestRegressor(n_estimators=100,random_state=42)
model_rf.fit(x_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(x_test)

# Calculate performance metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mape_rf = np.mean(np.abs((y_test - y_pred_rf) / np.abs(y_test)))
accuracy_rf = 100 * (1 - mape_rf)

# Print the performance metrics
print('Mean Absolute Error (MAE):', mae_rf)
print('Mean Squared Error (MSE):', mse_rf)
print('Root Mean Squared Error (RMSE):', rmse_rf)
print('Mean Absolute Percentage Error (MAPE):', round(mape_rf * 100, 2))
print('Accuracy:', round(accuracy_rf, 2))
# Out:
# Mean Absolute Error (MAE): 471.35783519974916
# Mean Squared Error (MSE): 5479103.006344534
# Root Mean Squared Error (RMSE): 2340.7483859536324
# Mean Absolute Percentage Error (MAPE): 0.83
# Accuracy: 99.17

# %%
import xgboost as xgb
#create and train the XGBoost model
model_xgb = xgb.XGBRegressor()
model_xgb.fit(x_train, y_train)

# Make predictions
y_pred_xgb = model_xgb.predict(x_test)

# Calculate performance metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb= mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mape_xgb = np.mean(np.abs((y_test - y_pred_xgb) / np.abs(y_test)))
accuracy_xgb = 100 * (1 - mape_xgb)

# Print the performance metrics for XGBoost
print('XGBoost Metrics:')
print('Mean Absolute Error (MAE):', mae_xgb)
print('Mean Squared Error (MSE):', mse_xgb)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# XGBoost Metrics:
# Mean Absolute Error (MAE): 11660.167652522772
# Mean Squared Error (MSE): 456136813.70696974
# Mean Absolute Percentage Error (MAPE): 0.59
# Accuracy: 99.41

# %%
from sklearn.model_selection import ShuffleSplit, cross_val_score
model=LinearRegression()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-Validation Accuracy:",np.mean(results))
# Out:
# [0.43890919 0.4546851  0.44328833 0.45756731 0.44430867 0.44813794
#  0.44545733 0.44884674 0.43536681 0.45128504]
#
# Mean Cross-Validation Accuracy: 0.44678524561801974

# %%
model=DecisionTreeRegressor(max_depth=3)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-Validation Accuracy:",np.mean(results))
# Out:
# [0.61336675 0.57482795 0.62514461 0.54926174 0.67382551 0.53573894
#  0.63233928 0.55759906 0.48635043 0.54209422]
#
# Mean Cross-Validation Accuracy: 0.5790548490466266

# %%
model=RandomForestRegressor(random_state=42)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-Validation Accuracy:",np.mean(results))
# Out:
# [0.99084289 0.98844722 0.98973826 0.98739116 0.98755329 0.9831427
#  0.99195875 0.99219502 0.98839813 0.98565477]
#
# Mean Cross-Validation Accuracy: 0.9885322170865122

# %%
model_xgb = xgb.XGBRegressor(objective='reg:squarederror',random_state=42)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
results_xgb=cross_val_score(model_xgb,x,y,cv=ssplit)
print('Cross-Validation')
print(results_xgb)
print("\nMean Cross-Validation Accuracy:",np.mean(results_xgb))
# Out:
# Cross-Validation
# [0.98747194 0.98206715 0.98205244 0.98996393 0.98822083 0.9899425
#  0.98682445 0.98562992 0.98010054 0.99259232]
#
# Mean Cross-Validation Accuracy: 0.9864866007950697

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle
from xgboost import XGBRegressor

# Example: Train a model (XGBoost Regressor as an example)
model_xgb = XGBRegressor()
model_xgb.fit(x_train, y_train)

# Save the trained model to a file using pickle
with open('hr.pkl', 'wb') as file:
    pickle.dump(model_xgb, file)

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
with open('schr.pkl', 'wb') as scaler_file:
    pickle.dump(sc, scaler_file)

# %%
# Define the content of the updated Streamlit script
streamlit_code = """
import streamlit as st
import pickle
import numpy as np

# Load the trained XGBoost model and scaler
with open('hr.pkl', 'rb') as model_file:
    model = pickle.load(model_file)

with open('schr.pkl', 'rb') as scaler_file:
    scaler = pickle.load(scaler_file)

# Create the web app
st.title('Salary Prediction App')

# Input fields
age = st.number_input('Age', min_value=0, max_value=120, value=30)
education = st.selectbox('Education Level', ['High School or less', 'Intermediate', 'Graduation', 'PG'])
experience_months = st.number_input('Months of Experience', min_value=0, max_value=600, value=60)  # Assuming max experience is 50 years

# Convert education to numeric encoding
education_mapping = {'High School or less': 0, 'Intermediate': 1, 'Graduation': 2, 'PG': 3}
education_encoded = education_mapping[education]

# Prepare the feature vector
features = np.array([[age, education_encoded, experience_months]], dtype=np.float64)

# Scale the features
features_scaled = scaler.transform(features)

# Predict salary
predicted_salary = model.predict(features_scaled)

# Display the result
st.write(f"Predicted Salary: ${predicted_salary[0]:,.2f}")
"""

# Specify the file path where the hrapp.py file will be saved
file_path = 'hrapp.py'

# Write the content to the file
with open(file_path, 'w') as file:
    file.write(streamlit_code)

print(f"File '{file_path}' has been saved.")
# Out:
# File 'hrapp.py' has been saved.
